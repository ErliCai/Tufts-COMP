# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.Graph()
G.add_node(1)
G.add_nodes_from([2, 3])
G.add_edge(1,2)
G.add_edge(1,2)
nx.draw(G)

# H = nx.path_graph(4)
# G.add_nodes_from(H)
# nx.draw(G)

# %%
G.add_edge(1,2)
e = (2,3)
G.add_edge(*e)
nx.draw(G)

# %%
G.clear()
G.add_edges_from([(1, 2)])
G.add_edges_from([(2, 3, {'weight': 3.1415})])
G.add_node(1)
G.add_edge(1, 2)
G.add_node("spam")        # adds node "spam"
G.add_nodes_from("spam")  # adds 4 nodes: 's', 'p', 'a', 'm'
G.add_edge(3, 'm')
# nx.draw(G)
G.number_of_nodes()
# Out:
# 8

# %%
G = nx.Graph([(1, 2, {"color": "yellow"})])
G.add_edge(1,3)
nx.draw(G)
G[1]
# Out:
# AtlasView({2: {'color': 'yellow'}, 3: {}})

# %%
import matplotlib.pyplot as plt
G = nx.petersen_graph()
plt.subplot(121)
nx.draw(G, with_labels=True, font_weight='bold')
plt.subplot(122)
nx.draw_shell(G, nlist=[range(5, 10), range(5)], with_labels=True, font_weight='bold')

# %%
G = nx.dodecahedral_graph()
shells = [[2, 3, 4, 5, 6], [8, 1, 0, 19, 18, 17, 16, 15, 14, 7], [9, 10, 11, 12, 13]]
nx.draw_shell(G, nlist=shells)

# %%
f = open("JumboWorld.txt")
line = f.readline()
a = line.split()
print(a)
line = f.readline()
print(line)
f.seek(0)
line = f.readline()
print(line)
f.close()
# Out:
# ['Family', 'Hotel', 'Park', 'Day']
# Smith	Tusk Hotel	Jumbo Kingdom	Friday
#
# Family	Hotel	Park	Day

# %%
q1 = nx.Graph()
q1.add_nodes_from([1,2,3,4])
q1.add_edge(1,5)
nx.draw(q1)
pos=nx.spring_layout(q1)
labels={}
labels[1]=r'$b$'
labels[2]=r'$c$'
labels[3]=r'$d$'
labels[4]=r'$\alpha$'
nx.draw_networkx_labels(G,pos,labels,font_size=16)
# Out:
# {1: Text(1,0.0860722,'$b$'),
#  2: Text(-0.661253,0.93833,'$c$'),
#  3: Text(-0.351986,-0.949866,'$d$'),
#  4: Text(-0.875072,0.0194912,'$\\alpha$')}
